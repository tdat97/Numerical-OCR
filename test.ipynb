# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"]='1'

# %%
from utils.ocr import OcrEngine
import matplotlib.pyplot as plt

# %%
# img = plt.imread("./temp/test_date_100cm.jpg")
img = plt.imread("./temp/test_date_120cm.jpg")
# img = plt.imread("./temp/test_date_50cm_5CRO.jpg")
# img = plt.imread("./temp/test_date_80cm_5CRO.jpg")
plt.imshow(img)

# %%
ocr_engine = OcrEngine("./models/date_ocr.h5")
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
ocr_engine(img)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# '2022.11.06'
